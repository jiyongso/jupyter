# %%
# %matplotlib inline
import sys
from numba import jit
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(0.0, 1.0, 0.001)

# %%
y1 = np.exp(-x**2/0.003)
y2 = np.exp(-(x-1.0)**2/0.001)
#plt.plot(x , y1)
#plt.plot(x, y2)
plt.plot(x, y1*y2)
