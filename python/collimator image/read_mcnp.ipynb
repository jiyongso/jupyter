# %%
# %matplotlib inline
#%matplotlib notebook
#%matplotlib widget
import matplotlib 
import numpy as np
import pandas as pd
#import ipywidgets
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter

# Excel data file
datafile1 = r"/Users/jiyong/research/HRMC/H-RMC_MCNP.xlsx"
datafile2 = r"/Users/jiyong/research/HRMC/H-RMC2_MCNP.xlsx"

# use LaTeX, choose nice some looking fonts and tweak some settings
matplotlib.rc('font', family='serif')
matplotlib.rc('font', size=16)
matplotlib.rc('legend', fontsize=16)
matplotlib.rc('legend', numpoints=1)
matplotlib.rc('legend', handlelength=1.5)
matplotlib.rc('legend', frameon=False)
matplotlib.rc('xtick.major', pad=7)
matplotlib.rc('xtick.minor', pad=7)
matplotlib.rc('text', usetex=True)
# matplotlib.rc('text.latex', 
#               preamble=[r'\usepackage[T1]{fontenc}',
#                         r'\usepackage{amsmath}',
#                         r'\usepackage{txfonts}',
#                         r'\usepackage{textcomp}'])

matplotlib.rc('figure', figsize=(12, 9))

# Excel data file
datafile1 = r"/Users/jiyong/research/HRMC/H-RMC_MCNP.xlsx"
datafile2 = r"/Users/jiyong/research/HRMC/H-RMC2_MCNP.xlsx"

# %%
mcnp1 = pd.read_excel(datafile1, skiprows=[0,])
mcnp2 = pd.read_excel(datafile2, skiprows=[0,])

# %%
len(mcnp2.columns)
# Out:
# 30

# %%
mcnp2.
# Out:
#      2.5 cm    aveage  0.00028921080332409965  Unnamed: 3  Unnamed: 4  \
# 0       NaN       min                0.000167         NaN         NaN
# 1      30.0       max                0.000376         NaN         0.0
# 2       0.0  0.000372                0.989899         NaN         0.0
# 3       1.0  0.000372                0.988038         NaN         1.0
# 4       2.0  0.000372                0.988304         NaN         2.0
# ..      ...       ...                     ...         ...         ...
# 358   356.0  0.000367                0.975013         NaN       356.0
# 359   357.0  0.000367                0.976342         NaN       357.0
# 360   358.0   0.00037                0.984583         NaN       358.0
# 361   359.0   0.00037                0.984583         NaN       359.0
# 362   360.0  0.000371                0.986975         NaN       360.0
#
#      aveage.1  0.0002461747922437673  Unnamed: 7  Unnamed: 8   5 cm  ...  \
# 0         min               0.000176         NaN         NaN    NaN  ...
# 1         max               0.000329         NaN         NaN   30.0  ...
# 2    0.000243               0.737849         NaN         NaN    0.0  ...
# 3    0.000244               0.740887         NaN         NaN    1.0  ...
# 4    0.000244               0.742102         NaN         NaN    2.0  ...
# ..        ...                    ...         ...         ...    ...  ...
# 358  0.000236               0.717497         NaN         NaN  356.0  ...
# 359  0.000236               0.717193         NaN         NaN  357.0  ...
# 360  0.000238               0.723876         NaN         NaN  358.0  ...
# 361   0.00024               0.729040         NaN         NaN  359.0  ...
# 362  0.000243               0.737849         NaN         NaN  360.0  ...
#
#     0.0004017252077562325  Unnamed: 21  Unnamed: 22  aveage.5  \
# 0                0.000223          NaN          NaN       min
# 1                0.000517          NaN         60.0       max
# 2                0.977778          NaN          0.0  0.000314
# 3                0.977778          NaN          1.0  0.000313
# 4                0.979710          NaN          2.0  0.000313
# ..                    ...          ...          ...       ...
# 358              0.980483          NaN        356.0  0.000305
# 359              0.978937          NaN        357.0  0.000307
# 360              0.977005          NaN        358.0   0.00031
# 361              0.977971          NaN        359.0  0.000311
# 362              0.977391          NaN        360.0  0.000313
#
#     0.0003363110803324097  Unnamed: 25  Unnamed: 26      r     θ    Φ
# 0                0.000236          NaN          NaN  110.0  30.0  0.0
# 1                0.000459          NaN          NaN  110.0  60.0  0.0
# 2                0.684038          NaN          NaN    NaN   NaN  NaN
# 3                0.683166          NaN          NaN    NaN   NaN  NaN
# 4                0.682294          NaN          NaN    NaN   NaN  NaN
# ..                    ...          ...          ...    ...   ...  ...
# 358              0.665504          NaN          NaN    NaN   NaN  NaN
# 359              0.668775          NaN          NaN    NaN   NaN  NaN
# 360              0.675098          NaN          NaN    NaN   NaN  NaN
# 361              0.679241          NaN          NaN    NaN   NaN  NaN
# 362              0.683602          NaN          NaN    NaN   NaN  NaN
#
# [363 rows x 30 columns]
