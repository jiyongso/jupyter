# %%
# %matplotlib inline
#%matplotlib notebook
#%matplotlib widget
import matplotlib 
import numpy as np
import pandas as pd
import os, sys, time, pickle
#import ipywidgets
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
from mpl_toolkits.mplot3d.art3d import Poly3DCollection    

from scipy import optimize
# use LaTeX, choose nice some looking fonts and tweak some settings
matplotlib.rc('font', family='serif')
matplotlib.rc('font', size=16)
matplotlib.rc('legend', fontsize=16)
matplotlib.rc('legend', numpoints=1)
matplotlib.rc('legend', handlelength=1.5)
matplotlib.rc('legend', frameon=True)
matplotlib.rc('xtick.major', pad=7)
matplotlib.rc('xtick', direction="in")
matplotlib.rc('ytick', direction="in")
matplotlib.rc('xtick', top = True)
matplotlib.rc('ytick', right =True )
matplotlib.rc('xtick.minor', pad=7)
matplotlib.rc('text', usetex=True)
# matplotlib.rc('text.latex', 
#               preamble=[r'\usepackage[T1]{fontenc}',
#                         r'\usepackage{amsmath}',
#                         r'\usepackage{txfonts}',
#                         r'\usepackage{textcomp}'])

matplotlib.rc('figure', figsize=(12, 9))

# %%
e1 = np.arange(0.01, 10.0, 0.001)
e2 = 10.0 - e1
plt.plot(e1, 5000*np.log(e1))
plt.plot(e1, 6000*np.log(10.0-e1))
plt.plot(e1, 5000*np.log(e1)+6000*np.log(10.0-e1))
#plt.yscale('log')

# %%
def factorial(n):
    if n in (0, 1):
        return 1
    else :
        return n*factorial(n-1)

# %%
x=np.arange(0.001, 1.0, 0.001)
y = factorial(10)/factorial(6)/factorial(4)*(x)**6 * (1-x)**4

# %%
plt.plot(x, y)

# %%
p11=0.2*0.4+0.2*0.5 + 0.6*3./11.
p12 = 0.6*3./11.
p12/p11
# Out:
# 0.4761904761904761

# %%
p12
# Out:
# 0.1636363636363636

# %%
pp = np.linspace(0.001, 1.0, 1000)
hh = - pp*np.log10(pp)/np.log10(2.)

# %%
plt.plot(pp, hh)

# %%
from IPython.display import HTML
from matplotlib import animation, rc
# equivalent to rcParams['animation.html'] = 'html5'
rc('animation', html='html5')
fig, ax = plt.subplots()

ax.set_xlim(( 0, 2))
ax.set_ylim((-2, 2))

line, = ax.plot([], [], lw=2)
# initialization function: plot the background of each frame
def init():
    line.set_data([], [])
    return (line,)
# animation function. This is called sequentially
def animate(i):
    x = np.linspace(0, 2, 1000)
    y = np.sin(2 * np.pi * (x - 0.01 * i))
    line.set_data(x, y)
    return (line,)
anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=100, interval=20, blit=True)
HTML(anim.to_html5_video())
# Out:
# <video width="864" height="648" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
nn=np.arange(1, 100)
plt.plot(nn, (1+1./nn)**(nn+1))
plt.yscale('log')

# %%
xx = np.arange(0.001, 100.0, 0.001)
yy = xx**0.5 - np.log(xx)
plt.plot(xx, yy)
plt.yscale('log')
plt.xscale('log')

# %%
from timeit import default_timer as timer
from multiprocessing import Pool
import random
import time

def _sum(to):
    vsum = 0
    start = timer()
    while vsum < to:
        number = random.randint(1,10)
        vsum = vsum + number
        time.sleep(0.1)
    end = timer()
    return (vsum, end - start)

p = Pool(4)
result = p.map(func=_sum, iterable=(100, 100, 100, 100))
print(sorted(result, key=lambda item:item[1]))
# Out:
# [(101, 1.6021737609989941), (103, 1.7019453440007055), (107, 1.9025360950035974), (102, 2.0028164020041004)]

# %%
rr = np.ones(1000)
ind = 0
for ind in range(999):
    rr[ind+1]= np.sqrt(1.+rr[ind])

# %%
plt.plot( np.arange(1, 1001), rr)
plt.yscale('log')
plt.xscale('log')

# %%
nn = np.arange(1, 1000)
y = np.sin(1.+1/(nn+1))/np.sin(1.+1/nn)
plt.plot(nn, y)
plt.xscale('log')
