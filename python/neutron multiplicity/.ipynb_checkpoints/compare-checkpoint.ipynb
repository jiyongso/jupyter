# %%
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

#%matplotlib notebook
#%matplotlib widget
import matplotlib 
import numpy as np
import pandas as pd
import os, sys, time, random
#import ipywidgets
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
from mpl_toolkits.mplot3d.art3d import Poly3DCollection    
 
# use LaTeX, choose nice some looking fonts and tweak some settings
matplotlib.rc('font', family='serif')
matplotlib.rc('font', size=16)
matplotlib.rc('legend', fontsize=16)
matplotlib.rc('legend', numpoints=1)
matplotlib.rc('legend', handlelength=1.5)
matplotlib.rc('legend', frameon=True)
matplotlib.rc('xtick.major', pad=7)
matplotlib.rc('xtick', direction="in")
matplotlib.rc('ytick', direction="in")
matplotlib.rc('xtick', top = True)
matplotlib.rc('ytick', right =True )
matplotlib.rc('xtick.minor', pad=7)
matplotlib.rc('text', usetex=True)
# matplotlib.rc('text.latex', 
#               preamble=[r'\usepackage[T1]{fontenc}',
#                         r'\usepackage{amsmath}',
#                         r'\usepackage{txfonts}',
#                         r'\usepackage{textcomp}'])

matplotlib.rc('figure', figsize=(12, 9))

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
device = torch.device('cuda:0')

# %%
from ptrac import *
rawdatafolder = r"/home/jiyongso/jhjeon/multi4/multi4/ptrac_CGMF"
pkldatafolder = r"./data"
jjhdatafolder = r"/home/jiyongso/jhjeon/intermediate"

# %%
ptrac_analysis_all_save(rawdatafolder, 3)
# Out:
#           2      1000         0         8  1.00000E+00
#
#           2      1000         0         8  1.00000E+00
#
#           1      1000         0         8  1.00000E+00
#
#           2      1000         0         8  1.00000E+00
#
#           1      1000         0         8  1.00000E+00
#
#           2      1000         0         8  1.00000E+00
#
#           2      1000         0         8  1.00000E+00
#
#           1      1000         0         8  1.00000E+00
#
#           3      1000         0         8  1.00000E+00
#
#           1      1000         0         8  1.00000E+00
#
#           1      1000         0         8  1.00000E+00
#
#           1      1000         0         8  1.00000E+00
#
#           1      1000         0         8  1.00000E+00
#
#           2      1000         0         8  1.00000E+00
#
#           5      1000         0         8  1.00000E+00
#
#           1      1000         0         8  1.00000E+00
#
#           1      1000         0         8  1.00000E+00
#
#           1      1000         0         8  1.00000E+00
#
#           2      1000         0         8  1.00000E+00
#
#           1      1000         0         8  1.00000E+00

# %%
sjyanalysis = read_ptrac_analysis("./data/C3_analysis.pkl")
jjhanalysis = read_jjh(rawdatafolder, 3, None, 0)
#jjhnl, jjhpl = list((jjhanalysis0[0]).values()), list((jjhanalysis0[1]).values())
kks = sjyanalysis.keys()
sjynl = [sjyanalysis[kk] for kk in kks if kk.split("_")[2]=="neutron"]
sjypl = [sjyanalysis[kk] for kk in kks if kk.split("_")[2]=="photon"]

kks = jjhanalysis.keys()
jjhnl = [jjhanalysis[kk] for kk in kks if kk.split("_")[2]=="neutron"]
jjhpl = [jjhanalysis[kk] for kk in kks if kk.split("_")[2]=="photon"]

jjhn, jjhp = pd.concat(jjhnl), pd.concat(jjhpl)
sjyn, sjyp = pd.concat(sjynl), pd.concat(sjypl)

# %%
# jjhk = list(jjhanalysis0[1].keys())
# for k, v in sjyanalysis.items():
#     if k.endswith("photon"):
#         #print(k)
#         print(k, sjyanalysis[k].shape[0]-jjhanalysis0[1][k+"_analysis"].shape[0])

sjyreduce = ptrac_reduce(sjyanalysis, False)
jjhreduce = read_jjh(rawdatafolder, 3, None, 1)

# %%
sjycombine = ptrac_combine(sjyreduce)
# Out:
# {128, 129, 141, 142, 143, 321, 322, 323, 324, 325, 326, 327, 328, 329, 341, 342, 343, 221, 222, 223, 224, 225, 226, 227, 228, 229, 241, 242, 243, 121, 122, 123, 124, 125, 126, 127}
# {128, 1, 129, 521, 141, 142, 143, 321, 322, 323, 324, 325, 326, 327, 328, 329, 341, 342, 343, 221, 222, 223, 224, 225, 226, 227, 228, 229, 241, 242, 243, 121, 122, 123, 124, 125, 126, 127}
# set()
# {1, 521}

# %%
print(sjyreduce["C3_2_photon"][0:10])
# Out:
#       time  cell  Nhist origin
# 0  99400.0     1      2      E
# 1  99400.0   324      2      O
# 2  87542.0     1      3      E
# 3  29840.0     1      4      E
# 4  91117.0     1      5      E
# 5  12973.0     1      6      E
# 6  35184.0     1      7      E
# 7  60746.0     1      8      E
# 8  43387.0     1      9      E
# 9  13916.0     1     10      E

# %%
print(jjhreduce["C3_2_photon_reduced"][0:10])
# Out:
#       time  cell  Nhist         origin
# 0  99400.0     1      2  photoelectric
# 1  99400.0   324      2        compton
# 2  99400.0     1      2  photoelectric
# 3  87542.0     1      3  photoelectric
# 4  29840.0     1      4  photoelectric
# 5  91117.0     1      5  photoelectric
# 6  12973.0     1      6  photoelectric
# 7  35184.0     1      7  photoelectric
# 8  60746.0     1      8  photoelectric
# 9  43387.0     1      9  photoelectric

# %%
sjyanalysis["C3_2_neutron"][9:20]
# Out:
#        time  cell  Nhist origin
# 9   48848.0   121     11      C
# 10  48848.0   121     11      P
# 11  45178.0   226     12      C
# 12  56555.0   129     14      C
# 13  56555.0   342     14      C
# 14  86842.0   123     17      C
# 15  68971.0   126     18      P
# 16  21152.0   229     19      C
# 17  86553.0   221     21      C
# 18   5012.3   229     22      C
# 19  56672.0   229     23      C

# %%
sjycombine_n, sjycombine_p= ptrac_combine(sjyreduce)

# %%
sjycombine_n.hist("time", bins=300)
print(sjycombine_n.shape)
# Out:
# (21892, 4)

# %%
jjhcombine = np.loadtxt(os.path.join(rawdatafolder, "C3_neutron.o"))
histx, histy, _ =plt.hist(jjhcombine, bins=300)

# %%
#kks = jjhreduce.keys()
jn = []
jp = []
for kk, df in jjhreduce.items() :
    if kk.split("_")[2]=="neutron":
        jn.append(df)
    elif kk.split("_")[2]=="photon":
        jp.append(df)
# Out:
# {'C3_1_neutron_reduced':          time  cell  Nhist             origin
#  0     39641.0   321      2  carbon scattering
#  1     37799.0   242      6  carbon scattering
#  2      6034.3   328     10  carbon scattering
#  3     90519.0   127     11  carbon scattering
#  4     84311.0   127     14  carbon scattering
#  ...       ...   ...    ...                ...
#  1134  32662.0   341   1515  carbon scattering
#  1135  32402.0   322   1515  carbon scattering
#  1136  94837.0   129   1516  carbon scattering
#  1137  37867.0   129   1519  proton production
#  1138  13563.0   326   1520  carbon scattering
#
#  [1139 rows x 4 columns],
#  'C3_1_photon_reduced':          time  cell  Nhist         origin
#  0     39641.0     1      2  photoelectric
#  1     61110.0     1      3  photoelectric
#  2      6362.3     1      4  photoelectric
#  3     55139.0     1      5  photoelectric
#  4     37798.0     1      6        compton
#  ...       ...   ...    ...            ...
#  1724  42662.0   221   1518        compton
#  1725  42662.0     1   1518  photoelectric
#  1726  37867.0     1   1519  photoelectric
#  1727  13563.0     1   1520  photoelectric
#  1728  23844.0     1   1521  photoelectric
#
#  [1729 rows x 4 columns],
#  'C3_2_neutron_reduced':          time  cell  Nhist             origin
#  0     29841.0   229      4  carbon scattering
#  1     91119.0   123      5  carbon scattering
#  2     12975.0   125      6  carbon scattering
#  3     60747.0   125      8  carbon scattering
#  4     43386.0   341      9  carbon scattering
#  ...       ...   ...    ...                ...
#  1100   3657.4   129   1459  carbon scattering
#  1101  51259.0   343   1461  carbon scattering
#  1102  11947.0   125   1462  carbon scattering
#  1103  20129.0   326   1463  carbon scattering
#  1104  81888.0   143   1464  carbon scattering
#
#  [1105 rows x 4 columns],
#  'C3_2_photon_reduced':          time  cell  Nhist         origin
#  0     99400.0     1      2  photoelectric
#  1     99400.0   324      2        compton
#  2     99400.0     1      2  photoelectric
#  3     87542.0     1      3  photoelectric
#  4     29840.0     1      4  photoelectric
#  ...       ...   ...    ...            ...
#  1618  87333.0   243   1465        compton
#  1619  87333.0     1   1465  photoelectric
#  1620  13197.0     1   1466  photoelectric
#  1621  42090.0     1   1467  photoelectric
#  1622  59097.0     1   1468  photoelectric
#
#  [1623 rows x 4 columns],
#  'C3_3_neutron_reduced':          time  cell  Nhist             origin
#  0      9259.5   327      4  carbon scattering
#  1      9260.3   225      4  carbon scattering
#  2     97248.0   342     10  carbon scattering
#  3     84781.0   227     11  carbon scattering
#  4     84785.0   223     11  carbon scattering
#  ...       ...   ...    ...                ...
#  1130  36333.0   142   1508  carbon scattering
#  1131  32879.0   129   1509  carbon scattering
#  1132  58481.0   226   1510  carbon scattering
#  1133  38927.0   328   1511  proton production
#  1134  55023.0   242   1512  carbon scattering
#
#  [1135 rows x 4 columns],
#  'C3_3_photon_reduced':          time  cell  Nhist         origin
#  0     43219.0     1      2  photoelectric
#  1     62559.0     1      3  photoelectric
#  2      9258.2     1      4  photoelectric
#  3     95326.0     1      5  photoelectric
#  4     21528.0     1      6  photoelectric
#  ...       ...   ...    ...            ...
#  1664  38927.0     1   1511  photoelectric
#  1665  38926.0   124   1511        compton
#  1666  38926.0     1   1511  photoelectric
#  1667  55022.0     1   1512  photoelectric
#  1668  42735.0     1   1513  photoelectric
#
#  [1669 rows x 4 columns],
#  'C3_4_neutron_reduced':           time  cell  Nhist             origin
#  0     18921.00   325      2  carbon scattering
#  1     37577.00   122      3  carbon scattering
#  2     83331.00   222      5  carbon scattering
#  3       167.66   121      7  proton production
#  4     53603.00   124     11  carbon scattering
#  ...        ...   ...    ...                ...
#  1059  40696.00   322   1447  carbon scattering
#  1060  71532.00   223   1448  carbon scattering
#  1061  71531.00   125   1448  carbon scattering
#  1062  71533.00   223   1448  carbon scattering
#  1063  72037.00   129   1448  carbon scattering
#
#  [1064 rows x 4 columns],
#  'C3_4_photon_reduced':          time  cell  Nhist         origin
#  0     18920.0     1      2  photoelectric
#  1     37576.0     1      3  photoelectric
#  2     63351.0     1      4  photoelectric
#  3     63351.0   242      4        compton
#  4     63351.0     1      4  photoelectric
#  ...       ...   ...    ...            ...
#  1614  40687.0     1   1447  photoelectric
#  1615  71543.0     1   1448  photoelectric
#  1616  68917.0     1   1449  photoelectric
#  1617  68917.0   321   1449        compton
#  1618  68917.0     1   1449  photoelectric
#
#  [1619 rows x 4 columns],
#  'C3_5_neutron_reduced':          time  cell  Nhist             origin
#  0     53627.0   341      2  carbon scattering
#  1     53627.0   329      2  carbon scattering
#  2      5649.4   126      3  proton production
#  3      5653.0   122      3  carbon scattering
#  4     53642.0   327      5  carbon scattering
#  ...       ...   ...    ...                ...
#  1084  32599.0   141   1518  proton production
#  1085  72179.0   323   1519  carbon scattering
#  1086  83065.0   222   1520  carbon scattering
#  1087  83068.0   322   1520  carbon scattering
#  1088  84026.0   228   1520  carbon scattering
#
#  [1089 rows x 4 columns],
#  'C3_5_photon_reduced':          time  cell  Nhist         origin
#  0     53626.0     1      2  photoelectric
#  1      5650.7     1      3  photoelectric
#  2     88540.0     1      4  photoelectric
#  3     53640.0     1      5  photoelectric
#  4     89093.0     1      6  photoelectric
#  ...       ...   ...    ...            ...
#  1691  32598.0     1   1518  photoelectric
#  1692  72179.0     1   1519  photoelectric
#  1693  83062.0     1   1520  photoelectric
#  1694  20759.0     1   1521        compton
#  1695  95343.0     1   1522  photoelectric
#
#  [1696 rows x 4 columns],
#  'C3_6_neutron_reduced':          time  cell  Nhist             origin
#  0     38443.0   141      2  carbon scattering
#  1     31478.0   323      4  carbon scattering
#  2     17939.0   128      5  carbon scattering
#  3      5603.7   121      7  carbon scattering
#  4      5658.1   321      7  carbon scattering
#  ...       ...   ...    ...                ...
#  1053   7066.9   326   1473  carbon scattering
#  1054  12688.0   241   1474  carbon scattering
#  1055  90052.0   324   1478  carbon scattering
#  1056  90048.0   327   1478  carbon scattering
#  1057  60431.0   222   1479  carbon scattering
#
#  [1058 rows x 4 columns],
#  'C3_6_photon_reduced':          time  cell  Nhist         origin
#  0     38442.0     1      2  photoelectric
#  1     97586.0     1      3  photoelectric
#  2     31477.0     1      4  photoelectric
#  3     17938.0     1      5  photoelectric
#  4     60906.0     1      6  photoelectric
#  ...       ...   ...    ...            ...
#  1650  94306.0     1   1476  photoelectric
#  1651  30760.0     1   1477  photoelectric
#  1652  90048.0     1   1478  photoelectric
#  1653  60425.0     1   1479  photoelectric
#  1654  25438.0     1   1480  photoelectric
#
#  [1655 rows x 4 columns],
#  'C3_7_neutron_reduced':          time  cell  Nhist             origin
#  0     98201.0   126      2  carbon scattering
#  1     62628.0   125      3  carbon scattering
#  2     73346.0   243      4  carbon scattering
#  3      5552.4   127      6  carbon scattering
#  4     66947.0   222      8  carbon scattering
#  ...       ...   ...    ...                ...
#  1112  83953.0   125   1499  carbon scattering
#  1113   4572.2   121   1502  carbon scattering
#  1114  35565.0   242   1504  carbon scattering
#  1115  45644.0   342   1506  carbon scattering
#  1116  67813.0   226   1508  proton production
#
#  [1117 rows x 4 columns],
#  'C3_7_photon_reduced':          time  cell  Nhist         origin
#  0     98204.0     1      2  photoelectric
#  1     62627.0     1      3  photoelectric
#  2     73346.0     1      4  photoelectric
#  3     73346.0   221      4        compton
#  4     73346.0     1      4  photoelectric
#  ...       ...   ...    ...            ...
#  1650  35840.0     1   1505  photoelectric
#  1651  45643.0     1   1506  photoelectric
#  1652  15875.0     1   1507  photoelectric
#  1653  67812.0     1   1508  photoelectric
#  1654  48195.0     1   1509  photoelectric
#
#  [1655 rows x 4 columns],
#  'C3_8_neutron_reduced':          time  cell  Nhist             origin
#  0     19242.0   241      2  carbon scattering
#  1     37645.0   122      4  carbon scattering
#  2     46536.0   328      7  carbon scattering
#  3     55873.0   143      8  carbon scattering
#  4      2721.4   242      9  carbon scattering
#  ...       ...   ...    ...                ...
#  1093  77937.0   122   1500  carbon scattering
#  1094  45182.0   222   1501  carbon scattering
#  1095  88434.0   226   1507  proton production
#  1096  37393.0   222   1509  carbon scattering
#  1097   8418.4   221   1512  carbon scattering
#
#  [1098 rows x 4 columns],
#  'C3_8_photon_reduced':          time  cell  Nhist         origin
#  0     19240.0     1      2  photoelectric
#  1     57960.0     1      3  photoelectric
#  2     37644.0     1      4  photoelectric
#  3     89792.0     1      5  photoelectric
#  4     64107.0     1      6  photoelectric
#  ...       ...   ...    ...            ...
#  1678  84693.0   227   1510        compton
#  1679  84693.0     1   1510  photoelectric
#  1680  59661.0     1   1511  photoelectric
#  1681   8417.8     1   1512  photoelectric
#  1682  84862.0     1   1513  photoelectric
#
#  [1683 rows x 4 columns],
#  'C3_9_neutron_reduced':          time  cell  Nhist             origin
#  0     44801.0   321      5  carbon scattering
#  1     72720.0   224      6  carbon scattering
#  2     35211.0   121      9  carbon scattering
#  3     91671.0   126     14  carbon scattering
#  4     91672.0   223     14  carbon scattering
#  ...       ...   ...    ...                ...
#  1133  84328.0   329   1479  carbon scattering
#  1134  30143.0   341   1480  carbon scattering
#  1135  30144.0   329   1480  carbon scattering
#  1136  30157.0   129   1480  carbon scattering
#  1137   6490.2   329   1482  carbon scattering
#
#  [1138 rows x 4 columns],
#  'C3_9_photon_reduced':          time  cell  Nhist         origin
#  0     12661.0     1      2  photoelectric
#  1     89297.0     1      3  photoelectric
#  2     10833.0     1      4  photoelectric
#  3     44798.0     1      5  photoelectric
#  4     72719.0   141      6        compton
#  ...       ...   ...    ...            ...
#  1624  19942.0     1   1481  photoelectric
#  1625   6488.9     1   1482  photoelectric
#  1626  62377.0     1   1483  photoelectric
#  1627  26775.0     1   1484  photoelectric
#  1628  52563.0     1   1485  photoelectric
#
#  [1629 rows x 4 columns],
#  'C3_10_neutron_reduced':          time  cell  Nhist             origin
#  0     77482.0   342      3  carbon scattering
#  1     87680.0   224      4  carbon scattering
#  2     75136.0   341      6  carbon scattering
#  3     75141.0   141      6  carbon scattering
#  4     41258.0   121      8  carbon scattering
#  ...       ...   ...    ...                ...
#  1090  75425.0   241   1461  carbon scattering
#  1091  82240.0   141   1463  carbon scattering
#  1092  82226.0   324   1463  proton production
#  1093  28208.0   322   1464  carbon scattering
#  1094  94940.0   243   1465  carbon scattering
#
#  [1095 rows x 4 columns],
#  'C3_10_photon_reduced':          time  cell  Nhist         origin
#  0     29650.0     1      2  photoelectric
#  1     77481.0     1      3  photoelectric
#  2     87687.0     1      4  photoelectric
#  3     14486.0     1      5  photoelectric
#  4     75132.0     1      6  photoelectric
#  ...       ...   ...    ...            ...
#  1613  75418.0     1   1461  photoelectric
#  1614  65067.0     1   1462  photoelectric
#  1615  82227.0     1   1463  photoelectric
#  1616  28205.0     1   1464  photoelectric
#  1617  94938.0     1   1465  photoelectric
#
#  [1618 rows x 4 columns],
#  'C3_11_neutron_reduced':          time  cell  Nhist             origin
#  0     84855.0   241      2  carbon scattering
#  1     39131.0   224      4  proton production
#  2     39430.0   143      7  proton production
#  3     22650.0   122      8  carbon scattering
#  4     56069.0   141     11  carbon scattering
#  ...       ...   ...    ...                ...
#  1115  61334.0   225   1490  carbon scattering
#  1116  81738.0   324   1493  carbon scattering
#  1117  20471.0   225   1494  carbon scattering
#  1118  20697.0   122   1496  carbon scattering
#  1119  13614.0   125   1497  carbon scattering
#
#  [1120 rows x 4 columns],
#  'C3_11_photon_reduced':          time  cell  Nhist         origin
#  0     84854.0     1      2  photoelectric
#  1     57266.0     1      3  photoelectric
#  2     39130.0     1      4  photoelectric
#  3     39675.0     1      5  photoelectric
#  4      1844.9     1      6  photoelectric
#  ...       ...   ...    ...            ...
#  1657  20695.0     1   1496  photoelectric
#  1658  13614.0     1   1497  photoelectric
#  1659  43929.0     1   1498  photoelectric
#  1660  37675.0     1   1499  photoelectric
#  1661  11843.0     1   1500  photoelectric
#
#  [1662 rows x 4 columns],
#  'C3_12_neutron_reduced':           time  cell  Nhist             origin
#  0     75918.00   342      4  proton production
#  1     91973.00   124      7  carbon scattering
#  2     14504.00   323      9  carbon scattering
#  3     14505.00   123      9  carbon scattering
#  4     25275.00   143     10  carbon scattering
#  ...        ...   ...    ...                ...
#  1128  59733.00   241   1509  proton production
#  1129    638.89   124   1510  carbon scattering
#  1130    639.44   224   1510  carbon scattering
#  1131    639.44   322   1510  carbon scattering
#  1132  65726.00   325   1513  carbon scattering
#
#  [1133 rows x 4 columns],
#  'C3_12_photon_reduced':          time  cell  Nhist         origin
#  0     40059.0     1      2  photoelectric
#  1     37712.0     1      3        compton
#  2     75917.0     1      4  photoelectric
#  3     86353.0     1      5  photoelectric
#  4     59411.0     1      6  photoelectric
#  ...       ...   ...    ...            ...
#  1646  58325.0     1   1514  photoelectric
#  1647  88849.0     1   1515  photoelectric
#  1648  82233.0     1   1516  photoelectric
#  1649  95481.0     1   1517  photoelectric
#  1650  80324.0     1   1518  photoelectric
#
#  [1651 rows x 4 columns],
#  'C3_13_neutron_reduced':          time  cell  Nhist             origin
#  0     12732.0   127      3  proton production
#  1     12730.0   329      3  carbon scattering
#  2     68028.0   122      5  carbon scattering
#  3     68027.0   322      5  carbon scattering
#  4     68026.0   326      5  proton production
#  ...       ...   ...    ...                ...
#  1075  52132.0   129   1470  carbon scattering
#  1076  53506.0   142   1472  carbon scattering
#  1077   7287.9   342   1473  carbon scattering
#  1078  40802.0   221   1474  carbon scattering
#  1079  25483.0   341   1475  proton production
#
#  [1080 rows x 4 columns],
#  'C3_13_photon_reduced':          time  cell  Nhist         origin
#  0     95264.0     1      2  photoelectric
#  1     12732.0     1      3  photoelectric
#  2     49991.0     1      4  photoelectric
#  3     68027.0     1      5  photoelectric
#  4     57261.0     1      6  photoelectric
#  ...       ...   ...    ...            ...
#  1631  53506.0     1   1472  photoelectric
#  1632   7286.7     1   1473  photoelectric
#  1633  40801.0     1   1474  photoelectric
#  1634  25482.0     1   1475  photoelectric
#  1635  79121.0     1   1476  photoelectric
#
#  [1636 rows x 4 columns],
#  'C3_14_neutron_reduced':          time  cell  Nhist             origin
#  0     16525.0   141      2  carbon scattering
#  1     87747.0   327      3  proton production
#  2     87748.0   229      3  carbon scattering
#  3     87746.0   124      3  proton production
#  4     88469.0   343      5  carbon scattering
#  ...       ...   ...    ...                ...
#  1143  94911.0   121   1527  carbon scattering
#  1144  46532.0   229   1528  carbon scattering
#  1145   7657.1   121   1529  carbon scattering
#  1146  79065.0   243   1530  carbon scattering
#  1147  56536.0   142   1531  carbon scattering
#
#  [1148 rows x 4 columns],
#  'C3_14_photon_reduced':          time  cell  Nhist         origin
#  0     16521.0     1      2  photoelectric
#  1     87746.0     1      3        compton
#  2     33074.0     1      4  photoelectric
#  3     88468.0     1      5  photoelectric
#  4     15243.0     1      6  photoelectric
#  ...       ...   ...    ...            ...
#  1696  79065.0     1   1530  photoelectric
#  1697  56531.0     1   1531  photoelectric
#  1698  99382.0     1   1532  photoelectric
#  1699  64438.0     1   1533  photoelectric
#  1700  33176.0     1   1534  photoelectric
#
#  [1701 rows x 4 columns],
#  'C3_15_neutron_reduced':          time  cell  Nhist             origin
#  0     98140.0   123      3  carbon scattering
#  1     96623.0   226      4  carbon scattering
#  2     53982.0   342      7  carbon scattering
#  3     97672.0   122      9  carbon scattering
#  4     97677.0   243      9  carbon scattering
#  ...       ...   ...    ...                ...
#  1103   8756.8   122   1477  carbon scattering
#  1104  87663.0   321   1479  carbon scattering
#  1105  74177.0   129   1483  carbon scattering
#  1106   1807.7   343   1484  carbon scattering
#  1107   7037.2   122   1486  carbon scattering
#
#  [1108 rows x 4 columns],
#  'C3_15_photon_reduced':          time  cell  Nhist         origin
#  0      4914.6     1      2  photoelectric
#  1     98141.0     1      3  photoelectric
#  2     98140.0   323      3        compton
#  3     98140.0     1      3  photoelectric
#  4     96622.0     1      4  photoelectric
#  ...       ...   ...    ...            ...
#  1642  59475.0     1   1487  photoelectric
#  1643  13050.0     1   1488  photoelectric
#  1644  13049.0   521   1488        compton
#  1645  13049.0     1   1488  photoelectric
#  1646  59603.0     1   1489  photoelectric
#
#  [1647 rows x 4 columns],
#  'C3_16_neutron_reduced':          time  cell  Nhist             origin
#  0     60878.0   227      2  proton production
#  1     21363.0   143      3  carbon scattering
#  2     21361.0   128      3  carbon scattering
#  3     15777.0   123      7  carbon scattering
#  4     15780.0   143      7  carbon scattering
#  ...       ...   ...    ...                ...
#  1158  52605.0   121   1494  carbon scattering
#  1159  56399.0   342   1495  carbon scattering
#  1160  46757.0   326   1496  proton production
#  1161  16535.0   324   1500  carbon scattering
#  1162  16534.0   142   1500  carbon scattering
#
#  [1163 rows x 4 columns],
#  'C3_16_photon_reduced':          time  cell  Nhist         origin
#  0     60877.0     1      2  photoelectric
#  1     21361.0     1      3  photoelectric
#  2     72211.0     1      4  photoelectric
#  3     60920.0     1      5  photoelectric
#  4     67280.0     1      6  photoelectric
#  ...       ...   ...    ...            ...
#  1650  56989.0     1   1497  photoelectric
#  1651  47085.0     1   1498  photoelectric
#  1652  97794.0     1   1499  photoelectric
#  1653  16533.0     1   1500  photoelectric
#  1654  62279.0     1   1501  photoelectric
#
#  [1655 rows x 4 columns],
#  'C3_17_neutron_reduced':          time  cell  Nhist             origin
#  0     16084.0   125      2  carbon scattering
#  1     16091.0   326      2  carbon scattering
#  2      8883.0   241      3  carbon scattering
#  3     90811.0   328      4  carbon scattering
#  4     90814.0   225      4  carbon scattering
#  ...       ...   ...    ...                ...
#  1162  75112.0   122   1527  carbon scattering
#  1163  88590.0   129   1528  carbon scattering
#  1164  88591.0   241   1528  carbon scattering
#  1165  88590.0   143   1528  carbon scattering
#  1166  11509.0   242   1530  carbon scattering
#
#  [1167 rows x 4 columns],
#  'C3_17_photon_reduced':          time  cell  Nhist         origin
#  0     16085.0     1      2  photoelectric
#  1      8882.1     1      3  photoelectric
#  2     90809.0     1      4  photoelectric
#  3     56206.0     1      5  photoelectric
#  4     40895.0     1      6  photoelectric
#  ...       ...   ...    ...            ...
#  1684  75111.0     1   1527  photoelectric
#  1685  88588.0     1   1528  photoelectric
#  1686  91562.0     1   1529  photoelectric
#  1687  11508.0     1   1530  photoelectric
#  1688  12454.0     1   1531  photoelectric
#
#  [1689 rows x 4 columns],
#  'C3_18_neutron_reduced':          time  cell  Nhist             origin
#  0     71287.0   326      2  carbon scattering
#  1     16000.0   343      5  carbon scattering
#  2     46716.0   142      8  carbon scattering
#  3     44118.0   128      9  carbon scattering
#  4     93462.0   243     10  carbon scattering
#  ...       ...   ...    ...                ...
#  1122  69618.0   227   1496  carbon scattering
#  1123  91468.0   127   1500  carbon scattering
#  1124  33689.0   141   1501  carbon scattering
#  1125  25826.0   221   1503  carbon scattering
#  1126  33938.0   325   1505  carbon scattering
#
#  [1127 rows x 4 columns],
#  'C3_18_photon_reduced':          time  cell  Nhist         origin
#  0     71287.0     1      2  photoelectric
#  1     55561.0     1      3  photoelectric
#  2     54253.0     1      4  photoelectric
#  3     15999.0     1      5  photoelectric
#  4     89517.0     1      6  photoelectric
#  ...       ...   ...    ...            ...
#  1659  25825.0     1   1503  photoelectric
#  1660  97312.0     1   1504  photoelectric
#  1661  33937.0     1   1505  photoelectric
#  1662  60736.0     1   1506  photoelectric
#  1663  38880.0     1   1507  photoelectric
#
#  [1664 rows x 4 columns],
#  'C3_19_neutron_reduced':          time  cell  Nhist             origin
#  0     15323.0   122      2  carbon scattering
#  1     15357.0   222      2  carbon scattering
#  2     62831.0   129      3  carbon scattering
#  3     62831.0   221      3  carbon scattering
#  4     41333.0   321      4  carbon scattering
#  ...       ...   ...    ...                ...
#  1092  58683.0   326   1460  carbon scattering
#  1093  58671.0   343   1460  carbon scattering
#  1094  30987.0   326   1464  carbon scattering
#  1095  54613.0   329   1465  carbon scattering
#  1096  88313.0   343   1466  carbon scattering
#
#  [1097 rows x 4 columns],
#  'C3_19_photon_reduced':          time  cell  Nhist         origin
#  0     15332.0     1      2  photoelectric
#  1     62831.0     1      3  photoelectric
#  2     59068.0     1      4  photoelectric
#  3     94433.0     1      5  photoelectric
#  4     53815.0     1      6  photoelectric
#  ...       ...   ...    ...            ...
#  1609  81275.0     1   1469  photoelectric
#  1610   9966.0     1   1470  photoelectric
#  1611   9965.4   226   1470        compton
#  1612   9965.4     1   1470  photoelectric
#  1613  65306.0     1   1471  photoelectric
#
#  [1614 rows x 4 columns],
#  'C3_20_neutron_reduced':          time  cell  Nhist             origin
#  0     75089.0   326      3  carbon scattering
#  1     66377.0   328      4  carbon scattering
#  2     66378.0   141      4  proton production
#  3     18116.0   122      5  carbon scattering
#  4     18116.0   142      5  carbon scattering
#  ...       ...   ...    ...                ...
#  1030  27815.0   123   1462  carbon scattering
#  1031  55655.0   324   1463  carbon scattering
#  1032  85180.0   228   1466  carbon scattering
#  1033  91733.0   227   1470  carbon scattering
#  1034  91733.0   324   1470  carbon scattering
#
#  [1035 rows x 4 columns],
#  'C3_20_photon_reduced':          time  cell  Nhist         origin
#  0     81697.0     1      2  photoelectric
#  1     75081.0     1      3  photoelectric
#  2     66377.0     1      4  photoelectric
#  3     18113.0     1      5  photoelectric
#  4     22984.0     1      6  photoelectric
#  ...       ...   ...    ...            ...
#  1619  85138.0     1   1466  photoelectric
#  1620  64589.0     1   1467  photoelectric
#  1621  18689.0     1   1468  photoelectric
#  1622  59194.0     1   1469  photoelectric
#  1623  91731.0     1   1470  photoelectric
#
#  [1624 rows x 4 columns]}

# %%
jjhcombine
# Out:
# array([2.410000e+02, 2.430000e+02, 5.010000e+02, ..., 1.999122e+06,
#        1.999794e+06, 1.999855e+06])

# %%
jjhrossi=np.loadtxt(os.path.join(rawdatafolder, "C3_photon_rossi.o"))
print(jjhrossi)
a=plt.hist(jjhrossi, bins=200)
plt.yscale('log')
# Out:
# [0. 0. 0. ... 0. 0. 0.]

# %%
plt.hist(sjyrossi_n, bins=100)
plt.yscale('log')
