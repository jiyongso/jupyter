# %%
import matplotlib.pyplot as plt
from pandas_datareader import data as pdr
import pandas as pd
from datetime import datetime
import matplotlib.dates as mdates
import matplotlib.ticker as mticker
#import yahoo_finance_pynterface as yahoo
import fix_yahoo_finance as fyf

# Depreciated modules (Don't use)
# from yahoo_finance import Share

# %%
appleClose = yahoo.Get.Prices("005930.KS")

# %%
appleClose.plot(y="Close", label="Samsung")

# %%
tsla = yahoo.Get.Prices("TSLA")

# %%
tsla.plot(y="Close", label="TSLA")

# %% [markdown]
# ## fix_yahoo_finance module 사용
#
# Import fix_yahoo_finance
#
#     import fix_yahoo_finance as fyf
#
# Do not use fyf.pdr_override(). **The jupyter become freeze!!!!**

# %%
stocks = ["APPL", "FB", "AMZN", "NFLX","GOOG"]

# %%
data = fyf.download("FB", start="2019-01-01", end="2019-04-30")

# %%
data.head()
# Out:
#            Adj Close                   Close                    High          \
#                 AAPL    NFLX     SPY    AAPL    NFLX     SPY    AAPL    NFLX
# Date
# 2018-12-31    157.07  267.66  248.82  157.74  267.66  249.92  159.36  270.10
# 2019-01-02    157.25  267.66  249.08  157.92  267.66  250.18  158.85  269.75
# 2019-01-03    141.58  271.20  243.14  142.19  271.20  244.21  145.72  275.79
# 2019-01-04    147.63  297.57  251.28  148.26  297.57  252.39  148.55  297.80
# 2019-01-07    147.30  315.34  253.26  147.93  315.34  254.38  148.83  316.80
#
#                        Low                    Open                    Volume  \
#                SPY    AAPL    NFLX     SPY    AAPL    NFLX     SPY      AAPL
# Date
# 2018-12-31  250.19  156.48  260.00  247.47  158.53  260.16  249.56  35003500
# 2019-01-02  251.21  154.23  256.58  245.95  154.89  259.28  245.98  37039700
# 2019-01-03  248.57  142.00  264.43  243.67  143.98  270.20  248.23  91244100
# ...

# %%
#ymm19 = fyf.download("YMM19.CBT", period = "1d", inverval = "1m", start="2019-04-28")
ymm19 = fyf.download("YMM19.CBT", period = "1d", interval = "2m", start="2019-04-29")
ymm19.tail()
# Out:
# [*********************100%***********************]  1 of 1 downloaded
#                               Open     High      Low    Close  Adj Close  \
# Datetime
# 2019-05-01 07:02:00-04:00  26643.0  26645.0  26640.0  26640.0    26640.0
# 2019-05-01 07:04:00-04:00  26641.0  26647.0  26641.0  26646.0    26646.0
# 2019-05-01 07:06:00-04:00  26647.0  26648.0  26646.0  26648.0    26648.0
# 2019-05-01 07:08:00-04:00  26649.0  26655.0  26648.0  26655.0    26655.0
# 2019-05-01 07:10:00-04:00  26655.0  26662.0  26655.0  26659.0    26659.0
#
#                            Volume
# Datetime
# 2019-05-01 07:02:00-04:00      54
# 2019-05-01 07:04:00-04:00      39
# 2019-05-01 07:06:00-04:00      23
# 2019-05-01 07:08:00-04:00      73
# 2019-05-01 07:10:00-04:00      67

# %%
ymm19.tail() #
# Out:
#                Open     High      Low    Close  Adj Close    Volume
# Date
# 2019-04-28  26500.0  26528.0  26499.0  26504.0    26504.0    136805
# 2019-04-29  26531.0  26584.0  26484.0  26552.0    26552.0  42977711

# %%
fyf.download?
