# %%
# %matplotlib inline
#%matplotlib notebook
#%matplotlib widget
import matplotlib 
import numpy as np
import pandas as pd
import os, sys
#import ipywidgets
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
from mpl_toolkits.mplot3d.art3d import Poly3DCollection    
 
# use LaTeX, choose nice some looking fonts and tweak some settings
matplotlib.rc('font', family='serif')
matplotlib.rc('font', size=16)
matplotlib.rc('legend', fontsize=16)
matplotlib.rc('legend', numpoints=1)
matplotlib.rc('legend', handlelength=1.5)
matplotlib.rc('legend', frameon=True)
matplotlib.rc('xtick.major', pad=7)
matplotlib.rc('xtick', direction="in")
matplotlib.rc('ytick', direction="in")
matplotlib.rc('xtick', top = True)
matplotlib.rc('ytick', right =True )
matplotlib.rc('xtick.minor', pad=7)
matplotlib.rc('text', usetex=True)
# matplotlib.rc('text.latex', 
#               preamble=[r'\usepackage[T1]{fontenc}',
#                         r'\usepackage{amsmath}',
#                         r'\usepackage{txfonts}',
#                         r'\usepackage{textcomp}'])

matplotlib.rc('figure', figsize=(12, 9))

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
device = torch.device('cuda:0')

# %%
N=20
dd = np.random.sample()
theta0 = (np.random.randint(30, 90, N)).astype(np.float)
phi0 = (np.random.randint(0, 360, N)).astype(np.float) 
theta  = theta0 +  np.random.choice([0.2, 0.35,  0.5, 0.65, 0.8], N)
phi = phi0 + np.random.choice([0.2, 0.35,  0.5, 0.65, 0.8], N)

# %%
for i in range(N):
    print(theta[i], phi[i])
# Out:
# 48.8 232.8
# 82.5 167.8
# 81.65 279.2
# 73.8 73.65
# 80.2 338.65
# 64.35 115.5
# 70.8 310.8
# 66.5 8.35
# 36.2 316.5
# 79.5 42.65
# 56.2 54.65
# 70.8 178.65
# 59.5 218.8
# 87.35 193.5
# 59.5 305.2
# 71.2 325.8
# 72.8 275.65
# 55.5 271.8
# 62.35 188.35
# 33.35 79.5

# %%
data = pd.read_csv("/home/jiyongso/modpattern_tht40phi120", sep="\t", header=None)
data.columns=["counts", "normcounts"]
data["counts"]/=500.0
data_e = np.random.poisson(data["counts"])
plt.plot(data_e, "r-")
plt.plot(data["counts"], "bo")

# %%
ee=np.random.poisson(data["counts"])-data["counts"]
ee.max(), ee.min()
# Out:
# (201, -182)

# %%
xx=np.arange(1, 10000)
xe = np.random.poisson(xx)
#plt.plot(xx)
#plt.plot(xe)
plt.plot(xx/xe)
#plt.yscale('log')
# Out:
# <ipython-input-52-7eeea1684ecc>:5: RuntimeWarning: divide by zero encountered in true_divide
#   plt.plot(xx/xe)
